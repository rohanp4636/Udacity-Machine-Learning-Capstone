# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
import pandas as pd
from glob import glob
import random
random.seed(8675309)

# define function to files
def load_files(path):
    data = np.array(glob(path))
    return data

#import all image categories and files into dictionary
print('------------------------------')
print('**Importing Training Data**')

train_images_cat = {}
total_images = 0
for i in range(0,10):
    index = "c" + str(i)
    folderName = 'imgs/train/' + index + '/*'
    train_images_cat[index] = load_files(folderName)
    total_images += len(train_images_cat[index])
    print('There are %d total images in category %s.' % (len(train_images_cat[index]), index))
    
print('There are %d total images.' % total_images)

#condense dictionary into array of tubles
train_data = []
for i in train_images_cat:
    for j in train_images_cat[i]:
        train_data.append((i, j))
print()
print('Sample format of train data. label and filepath.\n', train_data[0])
print('------------------------------')
print()

'''
#import testing data. testing data info is in excel file containing label and image name
#create tuple of (label, img_path) to pass onto next step
print('------------------------------')
print('**Importing Testing Data**')
testing_sheet = pd.read_csv("driver_imgs_list.csv/driver_imgs_list.csv")
testing_sheet = testing_sheet.drop(columns=['subject'])
test_data = []
for i in testing_sheet.iterrows():
    test_data.append( (i[1]['classname'], 'imgs/test/' + i[1]['img']) )

print('There are %d total testing images.' % len(test_data))  
print('Sample format of test data. label and filepath.\n', test_data[0])
print('------------------------------')
print()
'''
    
    
#shuffle list of tuples
random.shuffle(train_data)   


#reset training data to original
originalData = list(train_data)
def resetTrainData():
    return list(originalData)
# Out:
# ------------------------------
# **Importing Training Data**
# There are 2489 total images in category c0.
# There are 2267 total images in category c1.
# There are 2317 total images in category c2.
# There are 2346 total images in category c3.
# There are 2326 total images in category c4.
# There are 2312 total images in category c5.
# There are 2325 total images in category c6.
# There are 2002 total images in category c7.
# There are 1911 total images in category c8.
# There are 2129 total images in category c9.
# There are 22424 total images.
#
# Sample format of train data. label and filepath.
#  ('c6', 'imgs/train/c6\\img_0.jpg')
# ------------------------------
#
# 2780986970376
# 2780078907016
# ('c1', 'imgs/train/c1\\img_3482.jpg')
# ('c1', 'imgs/train/c1\\img_3482.jpg')
# ('c1', 'imgs/train/c1\\img_3482.jpg')
# ('c1', 'imgs/train/c1\\img_70978.jpg')
# 2780985176456
# ('c1', 'imgs/train/c1\\img_3482.jpg')
# ('c1', 'imgs/train/c1\\img_3482.jpg')

# %%
import cv2                
import matplotlib.pyplot as plt

#import images from filenames

def load_images(filename):
    img = cv2.imread(filename)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    #convert to greyscale option
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
   
    #display image
    plt.imshow(img)
    plt.show

print(train_data[0])
load_images(train_data[0][1])
# Out:
# ('c1', 'imgs/train/c1\\img_3482.jpg')

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def create4DTensor(img_path):
    # load image
    img = image.load_img(img_path, target_size=(224, 224))
    # convert image to 3d tensor
    img3d = image.img_to_array(img)
    # convert to 4d tensor
    return np.expand_dims(img3d, axis=0)

def processImages(data):
    tensors= []
    targets = []
    for i in tqdm(data):
        tensor = create4DTensor(i[1])
        target = i[0]

        tensors.append(tensor)
        targets.append(target)
    return tensors, targets




#-------------------------------------------------------------------------------
'''
#split data into training, validation, and testing
training_data = train_data[:2000]
validation_data = train_data[2001:2500]
testing_data = train_data[2501:3000]

train_images, train_targets = processImages(training_data)
valid_images, valid_targets = processImages(validation_data)
test_images, test_targets = processImages(testing_data)



train_images = np.vstack(train_images).astype('float32')/255
valid_images = np.vstack(valid_images).astype('float32')/255
test_images = np.vstack(test_images).astype('float32')/255


for i in range(0,len(train_targets)):
    train_targets[i]= train_targets[i][1:]
for i in range(0,len(valid_targets)):
    valid_targets[i]= valid_targets[i][1:]
for i in range(0,len(test_targets)):
    test_targets[i]= test_targets[i][1:]
    
train_targets = np_utils.to_categorical(np.array(train_targets), 10)
valid_targets = np_utils.to_categorical(np.array(valid_targets), 10)
test_targets = np_utils.to_categorical(np.array(test_targets), 10)
'''
#-------------------------------------------------------------------------------
#Use section above for smaller train/test. Use section below for batch training
#-------------------------------------------------------------------------------

validation_data = train_data[:2000] 
testing_data = train_data[2001:4000]

valid_images, valid_targets = processImages(validation_data)
test_images, test_targets = processImages(testing_data)

valid_images = np.vstack(valid_images).astype('float32')/255
test_images = np.vstack(test_images).astype('float32')/255

for i in range(0,len(valid_targets)):
    valid_targets[i]= valid_targets[i][1:]
for i in range(0,len(test_targets)):
    test_targets[i]= test_targets[i][1:]
    
valid_targets = np_utils.to_categorical(np.array(valid_targets), 10)
test_targets = np_utils.to_categorical(np.array(test_targets), 10)    

train_data = train_data[4001:]  
print(id(train_data))
def generator(input_data, batch_size):
    print(id(input_data))

            
#-------------------------------------------------------------------------------

x=generator(train_data,5)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 2/2000 [00:00<03:33,  9.35it/s]
#   0%|          | 10/2000 [00:00<02:36, 12.70it/s]
#   1%|          | 16/2000 [00:00<01:59, 16.60it/s]
#   1%|          | 22/2000 [00:00<01:35, 20.73it/s]
#   1%|▏         | 27/2000 [00:00<01:18, 25.02it/s]
#   2%|▏         | 32/2000 [00:00<01:07, 29.14it/s]
#   2%|▏         | 39/2000 [00:00<00:55, 35.19it/s]
#   2%|▏         | 46/2000 [00:00<00:47, 41.14it/s]
#   3%|▎         | 53/2000 [00:01<00:41, 46.57it/s]
#   3%|▎         | 60/2000 [00:01<00:38, 50.31it/s]
#   3%|▎         | 67/2000 [00:01<00:35, 54.30it/s]
#   4%|▎         | 74/2000 [00:01<00:33, 57.65it/s]
#   4%|▍         | 81/2000 [00:01<00:31, 60.35it/s]
#   4%|▍         | 88/2000 [00:01<00:31, 60.39it/s]
#   5%|▍         | 95/2000 [00:01<00:30, 61.53it/s]
#   5%|▌         | 103/2000 [00:01<00:29, 64.11it/s]
#   6%|▌         | 110/2000 [00:01<00:30, 62.92it/s]
#   6%|▌         | 119/2000 [00:02<00:28, 66.19it/s]
#   6%|▋         | 126/2000 [00:02<00:30, 60.96it/s]
#   7%|▋         | 133/2000 [00:02<00:34, 54.45it/s]
#   7%|▋         | 140/2000 [00:02<00:32, 56.51it/s]
#   7%|▋         | 146/2000 [00:02<00:32, 56.86it/s]
#   8%|▊         | 152/2000 [00:02<00:34, 53.59it/s]
#   8%|▊         | 158/2000 [00:02<00:33, 55.21it/s]
#   8%|▊         | 165/2000 [00:02<00:31, 58.73it/s]
#   9%|▊         | 172/2000 [00:03<00:31, 58.53it/s]
#   9%|▉         | 179/2000 [00:03<00:29, 61.55it/s]
#   9%|▉         | 186/2000 [00:03<00:29, 62.08it/s]
#  10%|▉         | 193/2000 [00:03<00:30, 58.39it/s]
#  10%|▉         | 199/2000 [00:03<00:33, 54.43it/s]
#  10%|█         | 205/2000 [00:03<00:37, 47.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-45e9c705efc5> in <module>()
#      60 testing_data = train_data[2001:4000]
#      61
# ---> 62 valid_images, valid_targets = processImages(validation_data)
#      63 test_images, test_targets = processImages(testing_data)
#      64
#
# <ipython-input-39-45e9c705efc5> in processImages(data)
#      14     targets = []
#      15     for i in tqdm(data):
# ---> 16         tensor = create4DTensor(i[1])
#      17         target = i[0]
#      18
#
# <ipython-input-39-45e9c705efc5> in create4DTensor(img_path)
#       4 def create4DTensor(img_path):
#       5     # load image
# ----> 6     img = image.load_img(img_path, target_size=(224, 224))
#       7     # convert image to 3d tensor
#       8     img3d = image.img_to_array(img)
#
# E:\Anaconda2\envs\dog-project\lib\site-packages\keras\preprocessing\image.py in load_img(path, grayscale, target_size)
#     318         raise ImportError('Could not import PIL.Image. '
#     319                           'The use of `array_to_img` requires PIL.')
# --> 320     img = pil_image.open(path)
#     321     if grayscale:
#     322         if img.mode != 'L':
#
# E:\Anaconda2\envs\dog-project\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2541
#    2542     if filename:
# -> 2543         fp = builtins.open(filename, "rb")
#    2544         exclusive_fp = True
#    2545
#
# KeyboardInterrupt:

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential

model = Sequential()

### TODO: Define your architecture.

model.add(Conv2D(4, (5, 5), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Conv2D(16, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Conv2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(GlobalAveragePooling2D())
          
model.add(Dropout(0.1))          
model.add(Dense(10, activation='softmax'))



model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 220, 220, 4)       304
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 110, 110, 4)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 106, 106, 16)      1616
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 53, 53, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 49, 49, 32)        12832
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 32)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 15,082.0
# Trainable params: 15,082.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 30

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_images, train_targets, 
          validation_data=(valid_images, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 2000 samples, validate on 499 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 2.30311, saving model to saved_models/weights.best.from_scratch.hdf5
# 10s - loss: 2.3049 - acc: 0.1180 - val_loss: 2.3031 - val_acc: 0.1042
# Epoch 2/30
# Epoch 00001: val_loss improved from 2.30311 to 2.30175, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.3024 - acc: 0.1155 - val_loss: 2.3017 - val_acc: 0.1042
# Epoch 3/30
# Epoch 00002: val_loss improved from 2.30175 to 2.30111, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.3016 - acc: 0.1160 - val_loss: 2.3011 - val_acc: 0.1162
# Epoch 4/30
# Epoch 00003: val_loss improved from 2.30111 to 2.29848, saving model to saved_models/weights.best.from_scratch.hdf5
# 7s - loss: 2.2993 - acc: 0.1220 - val_loss: 2.2985 - val_acc: 0.1102
# Epoch 5/30
# Epoch 00004: val_loss improved from 2.29848 to 2.29309, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.2959 - acc: 0.1275 - val_loss: 2.2931 - val_acc: 0.1703
# Epoch 6/30
# Epoch 00005: val_loss improved from 2.29309 to 2.28857, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.2899 - acc: 0.1330 - val_loss: 2.2886 - val_acc: 0.1343
# Epoch 7/30
# Epoch 00006: val_loss improved from 2.28857 to 2.27866, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.2801 - acc: 0.1575 - val_loss: 2.2787 - val_acc: 0.1142
# Epoch 8/30
# Epoch 00007: val_loss improved from 2.27866 to 2.26015, saving model to saved_models/weights.best.from_scratch.hdf5
# 7s - loss: 2.2660 - acc: 0.1555 - val_loss: 2.2602 - val_acc: 0.1683
# Epoch 9/30
# Epoch 00008: val_loss improved from 2.26015 to 2.22933, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.2459 - acc: 0.1650 - val_loss: 2.2293 - val_acc: 0.1804
# Epoch 10/30
# Epoch 00009: val_loss improved from 2.22933 to 2.21949, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.2280 - acc: 0.1735 - val_loss: 2.2195 - val_acc: 0.1804
# Epoch 11/30
# Epoch 00010: val_loss improved from 2.21949 to 2.16760, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.1959 - acc: 0.1845 - val_loss: 2.1676 - val_acc: 0.2124
# Epoch 12/30
# Epoch 00011: val_loss improved from 2.16760 to 2.13999, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.1723 - acc: 0.1975 - val_loss: 2.1400 - val_acc: 0.2004
# Epoch 13/30
# Epoch 00012: val_loss did not improve
# 8s - loss: 2.1441 - acc: 0.1960 - val_loss: 2.1635 - val_acc: 0.1623
# Epoch 14/30
# Epoch 00013: val_loss improved from 2.13999 to 2.10484, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.1353 - acc: 0.2105 - val_loss: 2.1048 - val_acc: 0.2265
# Epoch 15/30
# Epoch 00014: val_loss did not improve
# 8s - loss: 2.1094 - acc: 0.2175 - val_loss: 2.1374 - val_acc: 0.1844
# Epoch 16/30
# Epoch 00015: val_loss improved from 2.10484 to 2.03521, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.0957 - acc: 0.2260 - val_loss: 2.0352 - val_acc: 0.2545
# Epoch 17/30
# Epoch 00016: val_loss improved from 2.03521 to 2.03253, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.0717 - acc: 0.2335 - val_loss: 2.0325 - val_acc: 0.2545
# Epoch 18/30
# Epoch 00017: val_loss improved from 2.03253 to 2.01656, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.0518 - acc: 0.2355 - val_loss: 2.0166 - val_acc: 0.2325
# Epoch 19/30
# Epoch 00018: val_loss improved from 2.01656 to 1.99863, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 2.0233 - acc: 0.2710 - val_loss: 1.9986 - val_acc: 0.2144
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 8s - loss: 2.0022 - acc: 0.2595 - val_loss: 2.0952 - val_acc: 0.2244
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 8s - loss: 1.9803 - acc: 0.2595 - val_loss: 2.0131 - val_acc: 0.2685
# Epoch 22/30
# Epoch 00021: val_loss improved from 1.99863 to 1.93551, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 1.9744 - acc: 0.2680 - val_loss: 1.9355 - val_acc: 0.2745
# Epoch 23/30
# Epoch 00022: val_loss did not improve
# 8s - loss: 1.9693 - acc: 0.2740 - val_loss: 2.0379 - val_acc: 0.2545
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 8s - loss: 1.9275 - acc: 0.2835 - val_loss: 1.9536 - val_acc: 0.2645
# Epoch 25/30
# Epoch 00024: val_loss improved from 1.93551 to 1.89969, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 1.9195 - acc: 0.2845 - val_loss: 1.8997 - val_acc: 0.2906
# Epoch 26/30
# Epoch 00025: val_loss did not improve
# 8s - loss: 1.8915 - acc: 0.2990 - val_loss: 2.0695 - val_acc: 0.2445
# Epoch 27/30
# Epoch 00026: val_loss improved from 1.89969 to 1.86706, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 1.8825 - acc: 0.3020 - val_loss: 1.8671 - val_acc: 0.3026
# Epoch 28/30
# Epoch 00027: val_loss improved from 1.86706 to 1.81792, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 1.8944 - acc: 0.2960 - val_loss: 1.8179 - val_acc: 0.3267
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 8s - loss: 1.8394 - acc: 0.3190 - val_loss: 1.8467 - val_acc: 0.2806
# Epoch 30/30
# Epoch 00029: val_loss improved from 1.81792 to 1.79972, saving model to saved_models/weights.best.from_scratch.hdf5
# 8s - loss: 1.8591 - acc: 0.2980 - val_loss: 1.7997 - val_acc: 0.3046

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# get index of predicted dog breed for each image in test set
distracted_driver_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_images]

# report test accuracy
test_accuracy = 100*np.sum(np.array(distracted_driver_predictions)==np.argmax(test_targets, axis=1))/len(distracted_driver_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 30.6613%

# %%
#With a test accuracy of 30.661 % we are doing better than random chance since we have 10 different categories. (1/10 = 10%)

# %%
#model attemp 2

model = Sequential()

### TODO: Define your architecture.
model.add(BatchNormalization(input_shape=(224, 224, 3)))
model.add(Dropout(0.25))

model.add(Conv2D(4, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Conv2D(16, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Conv2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Flatten())
model.add(Dropout(0.25))   
model.add(Dense(10, activation='softmax'))



model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 224, 224, 3)       12
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 220, 220, 4)       304
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 110, 110, 4)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 106, 106, 16)      1616
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 53, 53, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 49, 49, 32)        12832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                184330
# =================================================================
# Total params: 199,094.0
# Trainable params: 199,088.0
# Non-trainable params: 6.0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 30

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch_v2.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_images, train_targets, 
          validation_data=(valid_images, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 2000 samples, validate on 499 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 1.98582, saving model to saved_models/weights.best.from_scratch_v2.hdf5
# 11s - loss: 2.4117 - acc: 0.1885 - val_loss: 1.9858 - val_acc: 0.4609
# Epoch 2/30
# Epoch 00001: val_loss improved from 1.98582 to 0.91736, saving model to saved_models/weights.best.from_scratch_v2.hdf5
# 10s - loss: 1.0544 - acc: 0.6635 - val_loss: 0.9174 - val_acc: 0.6954
# Epoch 3/30
# Epoch 00002: val_loss improved from 0.91736 to 0.44479, saving model to saved_models/weights.best.from_scratch_v2.hdf5
# 10s - loss: 0.3458 - acc: 0.8960 - val_loss: 0.4448 - val_acc: 0.8677
# Epoch 4/30
# Epoch 00003: val_loss improved from 0.44479 to 0.44328, saving model to saved_models/weights.best.from_scratch_v2.hdf5
# 10s - loss: 0.1508 - acc: 0.9555 - val_loss: 0.4433 - val_acc: 0.8798
# Epoch 5/30
# Epoch 00004: val_loss did not improve
# 10s - loss: 0.0841 - acc: 0.9700 - val_loss: 0.4712 - val_acc: 0.8938
# Epoch 6/30
# Epoch 00005: val_loss improved from 0.44328 to 0.38488, saving model to saved_models/weights.best.from_scratch_v2.hdf5
# 10s - loss: 0.0429 - acc: 0.9865 - val_loss: 0.3849 - val_acc: 0.9259
# Epoch 7/30
# Epoch 00006: val_loss did not improve
# 10s - loss: 0.0459 - acc: 0.9885 - val_loss: 0.4768 - val_acc: 0.8918
# Epoch 8/30
# Epoch 00007: val_loss did not improve
# 10s - loss: 0.0368 - acc: 0.9880 - val_loss: 0.3857 - val_acc: 0.9359
# Epoch 9/30
# Epoch 00008: val_loss did not improve
# 10s - loss: 0.0207 - acc: 0.9935 - val_loss: 0.4302 - val_acc: 0.9299
# Epoch 10/30
# Epoch 00009: val_loss did not improve
# 10s - loss: 0.0091 - acc: 0.9970 - val_loss: 0.4695 - val_acc: 0.9359
# Epoch 11/30
# Epoch 00010: val_loss did not improve
# 10s - loss: 0.0228 - acc: 0.9950 - val_loss: 0.5006 - val_acc: 0.9158
# Epoch 12/30
# Epoch 00011: val_loss did not improve
# 10s - loss: 0.0231 - acc: 0.9940 - val_loss: 0.5175 - val_acc: 0.9299
# Epoch 13/30
# Epoch 00012: val_loss did not improve
# 10s - loss: 0.0128 - acc: 0.9965 - val_loss: 0.4917 - val_acc: 0.9259
# Epoch 14/30
# Epoch 00013: val_loss did not improve
# 10s - loss: 0.0064 - acc: 0.9975 - val_loss: 0.4744 - val_acc: 0.9379
# Epoch 15/30
# Epoch 00014: val_loss did not improve
# 10s - loss: 0.0114 - acc: 0.9960 - val_loss: 0.7104 - val_acc: 0.9118
# Epoch 16/30
# Epoch 00015: val_loss did not improve
# 10s - loss: 0.0065 - acc: 0.9980 - val_loss: 0.9257 - val_acc: 0.9038
# Epoch 17/30
# Epoch 00016: val_loss did not improve
# 10s - loss: 0.0030 - acc: 0.9985 - val_loss: 0.7365 - val_acc: 0.9178
# Epoch 18/30
# Epoch 00017: val_loss did not improve
# 10s - loss: 0.0278 - acc: 0.9945 - val_loss: 0.5505 - val_acc: 0.9238
# Epoch 19/30
# Epoch 00018: val_loss did not improve
# 10s - loss: 0.0038 - acc: 0.9980 - val_loss: 0.6157 - val_acc: 0.9339
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 10s - loss: 0.0051 - acc: 0.9980 - val_loss: 0.5173 - val_acc: 0.9439
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 10s - loss: 0.0104 - acc: 0.9990 - val_loss: 0.6741 - val_acc: 0.9279
# Epoch 22/30
# Epoch 00021: val_loss did not improve
# 10s - loss: 0.0110 - acc: 0.9975 - val_loss: 0.4776 - val_acc: 0.9319
# Epoch 23/30
# Epoch 00022: val_loss did not improve
# 10s - loss: 3.9819e-04 - acc: 1.0000 - val_loss: 0.5102 - val_acc: 0.9439
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 10s - loss: 0.0090 - acc: 0.9970 - val_loss: 0.6754 - val_acc: 0.9379
# Epoch 25/30
# Epoch 00024: val_loss did not improve
# 10s - loss: 0.0143 - acc: 0.9970 - val_loss: 0.6243 - val_acc: 0.9299
# Epoch 26/30
# Epoch 00025: val_loss did not improve
# 10s - loss: 0.0083 - acc: 0.9985 - val_loss: 0.4978 - val_acc: 0.9399
# Epoch 27/30
# Epoch 00026: val_loss did not improve
# 10s - loss: 0.0064 - acc: 0.9985 - val_loss: 0.5488 - val_acc: 0.9319
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 10s - loss: 0.0056 - acc: 0.9980 - val_loss: 0.6638 - val_acc: 0.9399
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 10s - loss: 0.0107 - acc: 0.9990 - val_loss: 0.5605 - val_acc: 0.9459
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 10s - loss: 3.5611e-07 - acc: 1.0000 - val_loss: 0.6077 - val_acc: 0.9379

# %%
model.load_weights('saved_models/weights.best.from_scratch_v2.hdf5')

# get index of predicted dog breed for each image in test set
distracted_driver_predictions_v2 = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_images]

# report test accuracy
test_accuracy_v2 = 100*np.sum(np.array(distracted_driver_predictions_v2)==np.argmax(test_targets, axis=1))/len(distracted_driver_predictions_v2)
print('Test accuracy: %.4f%%' % test_accuracy_v2)
# Out:
# Test accuracy: 94.1884%

# %%
#Making significant gains in accuracy. Added batch normalization and flatten layer. Accuracy now at 94.1884%

# %%
#model attempt 3

model = Sequential()

### TODO: Define your architecture.
model.add(BatchNormalization(input_shape=(224, 224, 3)))
model.add(Dropout(0.25))

model.add(Conv2D(4, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Conv2D(16, (5, 5), activation='relu'))
model.add(Conv2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Conv2D(64, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Flatten())
model.add(Dropout(0.25))   
model.add(Dense(10, activation='softmax'))



model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_2 (Batch (None, 224, 224, 3)       12
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 220, 220, 4)       304
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 110, 110, 4)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 106, 106, 16)      1616
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 102, 102, 32)      12832
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 51, 51, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 47, 47, 64)        51264
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 33856)             0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 33856)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                338570
# =================================================================
# Total params: 404,598.0
# Trainable params: 404,592.0
# Non-trainable params: 6.0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 30

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch_v3.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_images, train_targets, 
          validation_data=(valid_images, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 2000 samples, validate on 499 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 1.63050, saving model to saved_models/weights.best.from_scratch_v3.hdf5
# 17s - loss: 2.1424 - acc: 0.2840 - val_loss: 1.6305 - val_acc: 0.5892
# Epoch 2/30
# Epoch 00001: val_loss improved from 1.63050 to 0.62869, saving model to saved_models/weights.best.from_scratch_v3.hdf5
# 16s - loss: 0.6508 - acc: 0.7915 - val_loss: 0.6287 - val_acc: 0.8257
# Epoch 3/30
# Epoch 00002: val_loss improved from 0.62869 to 0.35909, saving model to saved_models/weights.best.from_scratch_v3.hdf5
# 16s - loss: 0.1806 - acc: 0.9440 - val_loss: 0.3591 - val_acc: 0.9058
# Epoch 4/30
# Epoch 00003: val_loss did not improve
# 16s - loss: 0.0643 - acc: 0.9765 - val_loss: 0.5694 - val_acc: 0.8737
# Epoch 5/30
# Epoch 00004: val_loss did not improve
# 16s - loss: 0.0560 - acc: 0.9860 - val_loss: 0.6040 - val_acc: 0.9078
# Epoch 6/30
# Epoch 00005: val_loss did not improve
# 16s - loss: 0.0240 - acc: 0.9925 - val_loss: 0.5901 - val_acc: 0.8978
# Epoch 7/30
# Epoch 00006: val_loss did not improve
# 15s - loss: 0.0284 - acc: 0.9935 - val_loss: 0.5391 - val_acc: 0.9178
# Epoch 8/30
# Epoch 00007: val_loss did not improve
# 15s - loss: 0.0187 - acc: 0.9940 - val_loss: 0.5684 - val_acc: 0.9238
# Epoch 9/30
# Epoch 00008: val_loss did not improve
# 15s - loss: 0.0256 - acc: 0.9945 - val_loss: 0.5347 - val_acc: 0.9259
# Epoch 10/30
# Epoch 00009: val_loss did not improve
# 15s - loss: 0.0100 - acc: 0.9980 - val_loss: 0.6278 - val_acc: 0.9238
# Epoch 11/30
# Epoch 00010: val_loss did not improve
# 15s - loss: 0.0115 - acc: 0.9975 - val_loss: 0.7107 - val_acc: 0.9198
# Epoch 12/30
# Epoch 00011: val_loss did not improve
# 15s - loss: 0.0068 - acc: 0.9975 - val_loss: 0.5788 - val_acc: 0.9319
# Epoch 13/30
# Epoch 00012: val_loss did not improve
# 15s - loss: 0.0264 - acc: 0.9965 - val_loss: 0.7863 - val_acc: 0.9359
# Epoch 14/30
# Epoch 00013: val_loss did not improve
# 15s - loss: 0.0139 - acc: 0.9965 - val_loss: 0.7267 - val_acc: 0.9259
# Epoch 15/30
# Epoch 00014: val_loss did not improve
# 15s - loss: 0.0068 - acc: 0.9975 - val_loss: 1.2116 - val_acc: 0.8898
# Epoch 16/30
# Epoch 00015: val_loss did not improve
# 15s - loss: 0.0226 - acc: 0.9960 - val_loss: 0.7670 - val_acc: 0.9259
# Epoch 17/30
# Epoch 00016: val_loss did not improve
# 15s - loss: 0.0169 - acc: 0.9975 - val_loss: 1.0054 - val_acc: 0.9118
# Epoch 18/30
# Epoch 00017: val_loss did not improve
# 15s - loss: 0.0090 - acc: 0.9980 - val_loss: 0.8536 - val_acc: 0.9218
# Epoch 19/30
# Epoch 00018: val_loss did not improve
# 15s - loss: 8.0001e-04 - acc: 0.9995 - val_loss: 0.8492 - val_acc: 0.9178
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 15s - loss: 0.0056 - acc: 0.9990 - val_loss: 0.8284 - val_acc: 0.9279
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 15s - loss: 0.0093 - acc: 0.9990 - val_loss: 0.8660 - val_acc: 0.9198
# Epoch 22/30
# Epoch 00021: val_loss did not improve
# 15s - loss: 0.0142 - acc: 0.9975 - val_loss: 0.8001 - val_acc: 0.9238
# Epoch 23/30
# Epoch 00022: val_loss did not improve
# 15s - loss: 0.0055 - acc: 0.9990 - val_loss: 0.9078 - val_acc: 0.9218
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 15s - loss: 0.0082 - acc: 0.9995 - val_loss: 0.9763 - val_acc: 0.9178
# Epoch 25/30
# Epoch 00024: val_loss did not improve
# 15s - loss: 0.0152 - acc: 0.9980 - val_loss: 0.8199 - val_acc: 0.9238
# Epoch 26/30
# Epoch 00025: val_loss did not improve
# 15s - loss: 0.0179 - acc: 0.9980 - val_loss: 1.0963 - val_acc: 0.9178
# Epoch 27/30
# Epoch 00026: val_loss did not improve
# 15s - loss: 0.0013 - acc: 0.9995 - val_loss: 1.2435 - val_acc: 0.8838
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 15s - loss: 0.0458 - acc: 0.9940 - val_loss: 1.0683 - val_acc: 0.9259
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 15s - loss: 0.0200 - acc: 0.9975 - val_loss: 0.9001 - val_acc: 0.9299
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 15s - loss: 0.0067 - acc: 0.9995 - val_loss: 0.8283 - val_acc: 0.9359

# %%
model.load_weights('saved_models/weights.best.from_scratch_v3.hdf5')

# get index of predicted dog breed for each image in test set
distracted_driver_predictions_v3 = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_images]

# report test accuracy
test_accuracy_v3 = 100*np.sum(np.array(distracted_driver_predictions_v3)==np.argmax(test_targets, axis=1))/len(distracted_driver_predictions_v3)
print('Test accuracy: %.4f%%' % test_accuracy_v3)
# Out:
# Test accuracy: 91.9840%

# %%
Accurary is now at 91.9840 %.
# Out:
#   File "<ipython-input-19-7d7e91f5d35d>", line 1
#     Accurary is now at 91.9840 %.
#                      ^
# SyntaxError: invalid syntax

# %%
#model attempt 4

model = Sequential()

### TODO: Define your architecture.
model.add(BatchNormalization(input_shape=(224, 224, 3)))
model.add(Dropout(0.25))

model.add(Conv2D(2, (5, 5), activation='relu'))
model.add(Conv2D(4, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Conv2D(8, (5, 5), activation='relu'))
model.add(Conv2D(16, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Conv2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.25))   
model.add(Dense(10, activation='softmax'))



model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_3 (Batch (None, 224, 224, 3)       12
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 220, 220, 2)       152
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 216, 216, 4)       204
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 108, 108, 4)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 104, 104, 8)       808
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 100, 100, 16)      3216
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 46, 46, 32)        12832
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 23, 23, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 16928)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                846450
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                510
# =================================================================
# Total params: 864,184.0
# Trainable params: 864,178.0
# Non-trainable params: 6.0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 30

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch_v4.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_images, train_targets, 
          validation_data=(valid_images, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 2000 samples, validate on 499 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 1.87180, saving model to saved_models/weights.best.from_scratch_v4.hdf5
# 19s - loss: 2.0370 - acc: 0.2895 - val_loss: 1.8718 - val_acc: 0.4910
# Epoch 2/30
# Epoch 00001: val_loss improved from 1.87180 to 0.78594, saving model to saved_models/weights.best.from_scratch_v4.hdf5
# 18s - loss: 1.0430 - acc: 0.6615 - val_loss: 0.7859 - val_acc: 0.8116
# Epoch 3/30
# Epoch 00002: val_loss improved from 0.78594 to 0.52987, saving model to saved_models/weights.best.from_scratch_v4.hdf5
# 18s - loss: 0.5687 - acc: 0.8105 - val_loss: 0.5299 - val_acc: 0.8377
# Epoch 4/30
# Epoch 00003: val_loss improved from 0.52987 to 0.41274, saving model to saved_models/weights.best.from_scratch_v4.hdf5
# 18s - loss: 0.3586 - acc: 0.8745 - val_loss: 0.4127 - val_acc: 0.8878
# Epoch 5/30
# Epoch 00004: val_loss did not improve
# 17s - loss: 0.2575 - acc: 0.9155 - val_loss: 0.4744 - val_acc: 0.8697
# Epoch 6/30
# Epoch 00005: val_loss improved from 0.41274 to 0.37259, saving model to saved_models/weights.best.from_scratch_v4.hdf5
# 17s - loss: 0.2154 - acc: 0.9245 - val_loss: 0.3726 - val_acc: 0.9178
# Epoch 7/30
# Epoch 00006: val_loss did not improve
# 17s - loss: 0.1548 - acc: 0.9470 - val_loss: 0.4546 - val_acc: 0.8978
# Epoch 8/30
# Epoch 00007: val_loss did not improve
# 17s - loss: 0.1527 - acc: 0.9500 - val_loss: 0.4508 - val_acc: 0.9098
# Epoch 9/30
# Epoch 00008: val_loss did not improve
# 17s - loss: 0.1166 - acc: 0.9630 - val_loss: 0.6192 - val_acc: 0.8798
# Epoch 10/30
# Epoch 00009: val_loss did not improve
# 17s - loss: 0.0996 - acc: 0.9690 - val_loss: 0.5143 - val_acc: 0.9078
# Epoch 11/30
# Epoch 00010: val_loss did not improve
# 16s - loss: 0.0839 - acc: 0.9700 - val_loss: 0.5591 - val_acc: 0.9058
# Epoch 12/30
# Epoch 00011: val_loss did not improve
# 16s - loss: 0.0872 - acc: 0.9725 - val_loss: 0.8519 - val_acc: 0.8938
# Epoch 13/30
# Epoch 00012: val_loss did not improve
# 16s - loss: 0.0718 - acc: 0.9780 - val_loss: 0.6204 - val_acc: 0.9218
# Epoch 14/30
# Epoch 00013: val_loss did not improve
# 16s - loss: 0.0974 - acc: 0.9680 - val_loss: 0.4212 - val_acc: 0.9299
# Epoch 15/30
# Epoch 00014: val_loss improved from 0.37259 to 0.36183, saving model to saved_models/weights.best.from_scratch_v4.hdf5
# 16s - loss: 0.0644 - acc: 0.9780 - val_loss: 0.3618 - val_acc: 0.9339
# Epoch 16/30
# Epoch 00015: val_loss did not improve
# 16s - loss: 0.0520 - acc: 0.9825 - val_loss: 0.5112 - val_acc: 0.9359
# Epoch 17/30
# Epoch 00016: val_loss did not improve
# 16s - loss: 0.0556 - acc: 0.9840 - val_loss: 0.4801 - val_acc: 0.9238
# Epoch 18/30
# Epoch 00017: val_loss did not improve
# 16s - loss: 0.0470 - acc: 0.9830 - val_loss: 0.6291 - val_acc: 0.9138
# Epoch 19/30
# Epoch 00018: val_loss did not improve
# 16s - loss: 0.0771 - acc: 0.9725 - val_loss: 0.4673 - val_acc: 0.9359
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 16s - loss: 0.0488 - acc: 0.9795 - val_loss: 0.4426 - val_acc: 0.9379
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 16s - loss: 0.0681 - acc: 0.9815 - val_loss: 0.4634 - val_acc: 0.9198
# Epoch 22/30
# Epoch 00021: val_loss did not improve
# 16s - loss: 0.0436 - acc: 0.9850 - val_loss: 0.5237 - val_acc: 0.9379
# Epoch 23/30
# Epoch 00022: val_loss did not improve
# 16s - loss: 0.0646 - acc: 0.9825 - val_loss: 0.6067 - val_acc: 0.9218
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 16s - loss: 0.0432 - acc: 0.9830 - val_loss: 0.4905 - val_acc: 0.9319
# Epoch 25/30
# Epoch 00024: val_loss did not improve
# 16s - loss: 0.0491 - acc: 0.9845 - val_loss: 0.5700 - val_acc: 0.9299
# Epoch 26/30
# Epoch 00025: val_loss did not improve
# 15s - loss: 0.0474 - acc: 0.9875 - val_loss: 0.5265 - val_acc: 0.9419
# Epoch 27/30
# Epoch 00026: val_loss did not improve
# 15s - loss: 0.0427 - acc: 0.9895 - val_loss: 0.5279 - val_acc: 0.9379
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 15s - loss: 0.0423 - acc: 0.9895 - val_loss: 0.4240 - val_acc: 0.9479
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 15s - loss: 0.0420 - acc: 0.9880 - val_loss: 0.4203 - val_acc: 0.9319
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 15s - loss: 0.0462 - acc: 0.9865 - val_loss: 0.4065 - val_acc: 0.9399

# %%
model.load_weights('saved_models/weights.best.from_scratch_v4.hdf5')

# get index of predicted dog breed for each image in test set
distracted_driver_predictions_v4 = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_images]

# report test accuracy
test_accuracy_v4 = 100*np.sum(np.array(distracted_driver_predictions_v4)==np.argmax(test_targets, axis=1))/len(distracted_driver_predictions_v4)
print('Test accuracy: %.4f%%' % test_accuracy_v4)
# Out:
# Test accuracy: 94.1884%

# %%
94.1884%
# Out:
#   File "<ipython-input-24-92b0d0837e91>", line 1
#     94.1884%
#             ^
# SyntaxError: invalid syntax

# %%
work on visualizing a test image. batch training. and finally use pretrained model to see results..
# Out:
#   File "<ipython-input-28-f6a0d54c071f>", line 1
#     work on visualizing a test image. batch training. and finally use pretrained model to see results..
#           ^
# SyntaxError: invalid syntax
